# %% [markdown]
# # Compare different classifiers using HT29 dataset ( 14 phenotypes) in a binary fashion (each phenotype has its own data)

# %% [markdown]
# ## Obtain Data from database and only choose the positive examples to be in training set

# %%
#modify files and put them in another directory
import os
import numpy as np
import csv
directory = '/Users/jyhung/Downloads/SupplementalData/Jones_PNAS_2009_training_sets/'
newDirectory = '/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/'
#
def getNumlabel(strlabel):
    if strlabel in label_to_labelidx:
        return label_to_labelidx[strlabel]
    global curlabel
    print "LABEL: ", curlabel, strlabel
    label_to_labelidx[strlabel] = curlabel
    curlabel += 1
    return label_to_labelidx[strlabel]

for dirname, dirnames, filenames in os.walk(directory):

    label_names = np.array([])
    labels = []
    label_to_labelidx = {}
    curlabel = 1
    idNumbers = [] #each entry is (image number, object number)
    # print path to all filenames.
    #for each file, take out the lines that start with +1 
    #and add each to the label array to count the number in each class
    for filename in filenames:
        #filename_bare, file_extension = os.path.splitext(filename)
        #if file_extension == '.txt':
        #    print(filename_bare)#print(os.path.join(dirname, filename))
        if filename.endswith('_training.txt'):
            #print filename
            label_name = filename.split('_training.txt')[0]
            label_names = np.append(label_names, label_name)
            numlabel = getNumlabel(label_name)
            
            reader = csv.reader(open(os.path.join(directory,filename)), delimiter=' ')
            header = reader.next()
            print header
            with open(os.path.join(newDirectory,filename.split('.txt')[0] + '_modified.txt'), 'wb') as csvfile:
                
                writer = csv.writer(csvfile, delimiter=' ',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
                writer.writerow([header[0], header[2], header [3]])
                for vals in reader:
                    #idNumbers.append()
                    #print vals
                    writer.writerow([vals[0], vals[2], vals[3]])

# %%
import os
import numpy as np
import csv
directory = '/Users/jyhung/Downloads/SupplementalData/Jones_PNAS_2009_training_sets/'

#
def getNumlabel(strlabel):
    if strlabel in label_to_labelidx:
        return label_to_labelidx[strlabel]
    global curlabel
    print "LABEL: ", curlabel, strlabel
    label_to_labelidx[strlabel] = curlabel
    curlabel += 1
    return label_to_labelidx[strlabel]

for dirname, dirnames, filenames in os.walk(directory):

    label_names = np.array([])
    labels = []
    label_to_labelidx = {}
    curlabel = 1
    idNumbers = [] #each entry is (image number, object number)
    # print path to all filenames.
    #for each file, take out the lines that start with +1 
    #and add each to the label array to count the number in each class
    for filename in filenames:
        #filename_bare, file_extension = os.path.splitext(filename)
        #if file_extension == '.txt':
        #    print(filename_bare)#print(os.path.join(dirname, filename))
        if filename.endswith('actin_blebs_training.txt'):
            #print filename
            label_name = filename.split('_training.txt')[0]
            label_names = np.append(label_names, label_name)
            numlabel = getNumlabel(label_name)
            
            reader = csv.reader(open(os.path.join(directory,filename)), delimiter=' ')
            header = reader.next()
            print header
            for vals in reader:
                #idNumbers.append()
                print vals
                if vals[0] == '+1':
                    labels.append(numlabel)
                    idNumbers.append((int(vals[2]), int(vals[3])))
                    print labels, idNumbers

    
            
print label_names, len(label_names)

# %% [markdown]
# remove duplicates (samples with more than 1 phenotype) "ambiguously classified cells"

# %%
from collections import defaultdict
D = defaultdict(list)
for i,item in enumerate(idNumbers):
    D[item].append(i)

D = {k:v for k,v in D.items() if len(v)>1}
print D
duplicate_indices = np.array([])
for keys in D:
    duplicate_indices = np.append(duplicate_indices, D[keys])
    
print duplicate_indices
idNumbers_1occurance = [i for j, i in enumerate(idNumbers) if j not in duplicate_indices]
print idNumbers_1occurance

# %% [markdown]
# get data from database

# %%
#function to turn multiclass labels into binary 
def multiclassToBinary(class_one, labels):
    '''
    class_one: class of interest
    labels: array of class number of each sample
    RETURNS: modified labels array where class_one is the positive class and all other classes are in the negative class
    '''
    return [1 if x==class_one else 0 for x in labels]

# %%
#test, example
import sys
sys.path.insert(0, '/Users/jyhung/Documents/CellProfiler-Analyst/cpa/')
from dbconnect import *
import threading
from trainingset import TrainingSet
from datamodel import DataModel
from trainingset import TrainingSet
from StringIO import StringIO
import generalclassifier
from datatable import DataGrid
from sklearn.ensemble import AdaBoostClassifier

import wx
p = Properties.getInstance()
db = DBConnect.getInstance()
dm = DataModel.getInstance()

props = '/Users/jyhung/work/projects/subpop/analysis/input/2013-01-16_Handtraining_using_only_the_DNA_stain/training_sets/2013_01_17_Anne_AZ_DNA_training/az-dnaonly.properties'
ts = '/Users/jyhung/work/projects/subpop/analysis/input/2013-01-16_Handtraining_using_only_the_DNA_stain/training_sets/2013_01_17_Anne_AZ_DNA_training/Anne_DNA_66.txt'
nRules = 5
filter = None

classifier = AdaBoostClassifier(n_estimators=nRules)
GC = generalclassifier.GeneralClassifier(classifier)

p.LoadFile(props)
trainingSet = TrainingSet(p)
trainingSet.Load(ts)
print trainingSet.labels
print len(trainingSet.colnames)
print trainingSet.colnames
print trainingSet.values.shape
print trainingSet.values

# %%
import sys
sys.path.insert(0, '/Users/jyhung/Documents/CellProfiler-Analyst/cpa/')
from dbconnect import *
import threading
from trainingset import TrainingSet

def get_object_data(object_table, key):
    self.data[key] = db.GetCellData(key)
    return self.data[key][self.col_indices]

p = Properties.getInstance()
db = DBConnect.getInstance()
props ='/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/nirht.properties'
ts='/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/actin_blebs_training_modified.txt'
p.LoadFile(props)
trainingSet = TrainingSet(p)
trainingSet.Load(ts)

# %%
! grep classifier_ignore_columns /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/nirht.properties

# %%
trainingSet.values.shape
values = trainingSet.values
labels= trainingSet.label_matrix[:,2]

# %%
#print trainingSet.values.shape
#print trainingSet.colnames
#print trainingSet.values, trainingSet.values.shape
#print trainingSet.label_matrix[:,2]

# %%
import sys
sys.path.insert(0, '/Users/jyhung/Documents/CellProfiler-Analyst/cpa/')
import generalclassifier, multiclasssql
def XValidateBinary(classifier, labels, values):
    classifier = generalclassifier.GeneralClassifier(eval(classifier))
    unique_labels, inversed = np.unique(labels, return_inverse=True)
    num_classes = len(unique_labels) 
    for i in range(1, num_classes+1):
        labels_binary = multiclassToBinary(i, labels)
        scores = classifier.XValidate(labels_binary, values, folds=20, stratified=True)
        print scores.mean(), scores.std()

# %%
sum(labels==1)

# %%
unique_labels = np.unique(labels)
n_classes = len(unique_labels)
scorePerClass = np.zeros(n_classes)
predicted_labels = generalclassifier.GeneralClassifier(eval(classifier)).XValidatePredict(labels,values,folds=20, stratified=True)
print predicted_labels
for i in unique_labels:
    indices = (labels == (i))
    print i, sum(indices)
    #print predicted_labels[indices] == (i)
    predicted_correct = (predicted_labels[indices] == (i))
    print 1.0*sum(predicted_correct)/sum(indices)

# %%
#run to save training data (label and values) in npz files
import os
import sys
sys.path.insert(1, '/Users/jyhung/Documents/CellProfiler-Analyst/cpa/')
sys.path.insert(1, '/Users/jyhung/Documents/CellProfiler-Analyst/')
from dbconnect import *
import threading
from trainingset import TrainingSet
import generalclassifier, multiclasssql
from sklearn import ensemble, naive_bayes, grid_search, svm, lda, qda, tree, multiclass, linear_model, neighbors

directory = '/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/'
p = Properties.getInstance()
db = DBConnect.getInstance()
props =directory+'nirht.properties'
p.LoadFile(props)
trainingSet = TrainingSet(p)
for dirname, dirnames, filenames in os.walk(directory):
        for filename in sorted(filenames):

            if filename.endswith('_modified.txt'):
                ts=directory+filename
                print 'Loading training set %s ...' % ts
                trainingSet.Load(ts)
                print 'Accessing training set ...'
                values = trainingSet.values
                labels= trainingSet.label_matrix[:,2]
                labels = np.array([1 if x==1 else 2 for x in labels])#1 for positives, 2 for negatives
                np.savez(directory+filename.split('_modified.txt')[0], labels=labels, values=values)
                #np.save(directory+filename.split('_modified.txt')[0]+'_values', values)
# Out:
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/actin_blebs_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/actin_dots_junctions_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/anaphase_telophase_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/angular_cell_edges_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/crescent_nuclei_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/large_spread_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/long_projections_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/metaphase_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/motile_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/peas_in_a_pod_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/peripheral_actin_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/phospho_histone_h3_dots_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/prometaphase_training_modified.txt ...
# Accessing training set ...
# Loading training set /Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/prophase_training_modified.txt ...
# Accessing training set ...

# %% [markdown]
# ## Training for 1 phenotype

# %%
import sys
sys.path.insert(0, '/Users/jyhung/Documents/CellProfiler-Analyst/cpa/')
from dbconnect import *
import threading
from trainingset import TrainingSet

p = Properties.getInstance()
db = DBConnect.getInstance()
props ='/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/nirht.properties'
ts='/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/actin_blebs_training_modified.txt'
p.LoadFile(props)
trainingSet = TrainingSet(p)
trainingSet.Load(ts)

values = trainingSet.values
labels= trainingSet.label_matrix[:,2]

# %%
import sys
sys.path.insert(0, '/Users/jyhung/Documents/CellProfiler-Analyst/cpa/')
import generalclassifier, multiclasssql
from sklearn import ensemble, naive_bayes, grid_search, svm, lda, qda, tree, multiclass, linear_model, neighbors

classifier = 'ensemble.AdaBoostClassifier()'
def main(classifier, labels_, values_):
    classifier = generalclassifier.GeneralClassifier(eval(classifier))
    scores = classifier.XValidate(labels_, values_, folds=20, stratified=True)
    print scores.mean(), scores.std()

    print classifier.ClassificationReport(labels_, classifier.XValidatePredict(labels_,values_,folds=20, stratified=True))
main(classifier, labels, values)

# %% [markdown]
# ## Training for 14 phenotypes

# %%
#1 run to define tic and toc (a la matlab)
import time
def tic():
    #Homemade version of matlab tic and toc functions
    global startTime_for_tictoc
    startTime_for_tictoc = time.time()

def toc():
    if 'startTime_for_tictoc' in globals():
        print "Elapsed time is " + str(time.time() - startTime_for_tictoc) + " seconds."
    else:
        print "Toc: start time not set"

# %%
#2 run to define main function which gets training data from database and does CV
import os
import sys
sys.path.insert(1, '/Users/jyhung/Documents/CellProfiler-Analyst/cpa/')
sys.path.insert(1, '/Users/jyhung/Documents/CellProfiler-Analyst/')
from dbconnect import *
import threading
from trainingset import TrainingSet
import generalclassifier, multiclasssql
from sklearn import ensemble, naive_bayes, grid_search, svm, lda, qda, tree, multiclass, linear_model, neighbors

directory = '/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/'
p = Properties.getInstance()
db = DBConnect.getInstance()
props =directory+'nirht.properties'
p.LoadFile(props)
trainingSet = TrainingSet(p)

def main(classifier_obj):
    classifier = generalclassifier.GeneralClassifier(eval(classifier_obj))
    
    for dirname, dirnames, filenames in os.walk(directory):
        for filename in sorted(filenames):

            if filename.endswith('_modified.txt'):
                ts=directory+filename
                print 'Loading training set %s ...' % ts
                trainingSet.Load(ts)
                print 'Accessing training set ...'
                values = trainingSet.values
                labels= trainingSet.label_matrix[:,2]
                labels = np.array([1 if x==1 else 2 for x in labels])
                np.save(filename.split('_modified.txt')[0]+'_labels.txt', labels)
                np.save(filename.split('_modified.txt')[0]+'_values.txt', values)

                print filename, values.shape
                #print labels, values
                #%time classifier.XValidate(labels, values, folds=20, stratified=True)
                tic()
                print 'Scoring cells 1 ...'
                scores = classifier.XValidate(labels, values, folds=20, stratified=True)
                toc()
                print 'stratified 20 fold CV', scores.mean(), scores.std()
                #print 'Scoring cells 2 ...'
                #scores2 = classifier.XValidate(labels, values, folds=5, stratified=True)
                #print 'stratified 5 fold CV', scores2.mean(), scores2.std()
                '''
                try:
                    scores3 = classifier.XValidateBalancedClasses(labels, values, folds=5)
                    print 'undersampled (balanced)', scores3.mean(), scores3.std()
                except:
                    pass
                '''
                print classifier.ClassificationReport(labels, classifier.XValidatePredict(labels,values,folds=20, stratified=True))

# %%
#2 run to define main function which loads training data from local .npy files and does CV
import os
import sys
sys.path.insert(1, '/Users/jyhung/Documents/CellProfiler-Analyst/cpa/')
sys.path.insert(1, '/Users/jyhung/Documents/CellProfiler-Analyst/')
from dbconnect import *
import threading
from trainingset import TrainingSet
import generalclassifier, multiclasssql
from sklearn import cross_validation
from sklearn import ensemble, naive_bayes, grid_search, svm, lda, qda, tree, multiclass, linear_model, neighbors

directory = '/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/'

def main(classifier_obj):
    classifier = generalclassifier.GeneralClassifier(eval(classifier_obj))
    
    for dirname, dirnames, filenames in os.walk(directory):
        for filename in sorted(filenames):
            
            if filename.endswith('.npz'):
                print 'Loading training set ...'
                trainingSet=np.load(directory+filename)
                labels=trainingSet['labels']
                values=trainingSet['values']
                print filename, values.shape
                #print labels, values
                #%time classifier.XValidate(labels, values, folds=20, stratified=True)
                tic()
                print 'Scoring cells 1 ...'
                scores = classifier.XValidate(labels, values, folds=5, stratified=True)
                toc()
                print 'stratified 5 fold CV', scores.mean(), scores.std()
                print classifier.ClassificationReport(labels, classifier.XValidatePredict(labels,values,folds=5, stratified=True))

# %%
import numpy as np
#ddd=np.load(directory+'angular_cell_edges_training.npz')
ddd=np.load(directory+'anaphase_telophase_training.npz')
labels = ddd['labels']
values = ddd['values']
classifier_obj = "grid_search.GridSearchCV(svm.LinearSVC(),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
#classifier = generalclassifier.GeneralClassifier(eval(classifier_obj))
#print classifier.XValidate(labels, values, folds=20, stratified=True)
print cross_validation.cross_val_score(eval(classifier_obj), X=values, y=labels, cv=20)
# Out:
# [ 0.93548387  0.93548387  0.98924731  0.96774194  0.88172043  0.94623656
#   0.86021505  0.97826087  0.84782609  0.97826087  0.95652174  0.97826087
#   0.95652174  0.97802198  0.92307692  0.94505495  0.98901099  0.96703297
#   0.95604396  0.78021978]

# %%
import numpy as np
#ddd=np.load(directory+'angular_cell_edges_training.npz')
ddd=np.load(directory+'anaphase_telophase_training.npz')
labels = ddd['labels']
values = ddd['values']
print labels, values
classifier_obj = "grid_search.GridSearchCV(svm.LinearSVC(),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
#classifier = generalclassifier.GeneralClassifier(eval(classifier_obj))
#print classifier.XValidate(labels, values, folds=20, stratified=True)
print cross_validation.cross_val_score(eval(classifier_obj), X=values, y=labels, cv=20, n_jobs=1) #when n_jobs !=1, hangs

# %% [markdown]
# ## AdaBoost

# %%
#Adaboost 50
classifier = 'ensemble.AdaBoostClassifier()'
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 5.6129360199 seconds.
# stratified 5 fold CV 0.829004076878 0.0422210215265
#              precision    recall  f1-score   support
#
#           1       0.67      0.48      0.56       115
#           2       0.86      0.93      0.89       394
#
# avg / total       0.82      0.83      0.82       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 3.39117312431 seconds.
# stratified 5 fold CV 0.791092896175 0.0636558312892
#              precision    recall  f1-score   support
#
#           1       0.73      0.76      0.74       120
#           2       0.84      0.81      0.82       182
#
# avg / total       0.79      0.79      0.79       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 21.7887527943 seconds.
# stratified 5 fold CV 0.947356090209 0.041291594856
#              precision    recall  f1-score   support
#
#           1       0.72      0.78      0.75       187
#           2       0.97      0.97      0.97      1653
#
# avg / total       0.95      0.95      0.95      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 3.97036910057 seconds.
# stratified 5 fold CV 0.838185654008 0.0727573757203
#              precision    recall  f1-score   support
#
#           1       0.56      0.59      0.57        73
#           2       0.91      0.89      0.90       321
#
# avg / total       0.84      0.84      0.84       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 19.0503768921 seconds.
# stratified 5 fold CV 0.877192982456 0.0209222734737
#              precision    recall  f1-score   support
#
#           1       0.46      0.26      0.33       200
#           2       0.91      0.96      0.93      1510
#
# avg / total       0.85      0.88      0.86      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 5.29876089096 seconds.
# stratified 5 fold CV 0.797395888901 0.0226005379262
#              precision    recall  f1-score   support
#
#           1       0.75      0.72      0.73       202
#           2       0.82      0.85      0.84       316
#
# avg / total       0.80      0.80      0.80       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 4.09492015839 seconds.
# stratified 5 fold CV 0.824166666667 0.0841004699232
#              precision    recall  f1-score   support
#
#           1       0.41      0.47      0.44        59
#           2       0.91      0.88      0.90       345
#
# avg / total       0.84      0.82      0.83       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 10.1183209419 seconds.
# stratified 5 fold CV 0.87664160401 0.0723753398288
#              precision    recall  f1-score   support
#
#           1       0.88      0.92      0.90       568
#           2       0.87      0.81      0.84       380
#
# avg / total       0.88      0.88      0.88       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 10.494781971 seconds.
# stratified 5 fold CV 0.785481197555 0.0508114868
#              precision    recall  f1-score   support
#
#           1       0.44      0.40      0.42       190
#           2       0.86      0.88      0.87       794
#
# avg / total       0.78      0.79      0.78       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 10.5384659767 seconds.
# stratified 5 fold CV 0.941576260526 0.0416734129992
#              precision    recall  f1-score   support
#
#           1       0.04      0.03      0.03        34
#           2       0.97      0.97      0.97       957
#
# avg / total       0.93      0.94      0.94       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 7.89027285576 seconds.
# stratified 5 fold CV 0.930041350085 0.0521925500373
#              precision    recall  f1-score   support
#
#           1       0.62      0.56      0.59        61
#           2       0.96      0.97      0.96       623
#
# avg / total       0.93      0.93      0.93       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 9.49232506752 seconds.
# stratified 5 fold CV 0.889139413722 0.0611115263481
#              precision    recall  f1-score   support
#
#           1       0.80      0.84      0.82       266
#           2       0.93      0.91      0.92       628
#
# avg / total       0.89      0.89      0.89       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 30.3786799908 seconds.
# stratified 5 fold CV 0.898998182479 0.0776963042961
#              precision    recall  f1-score   support
#
#           1       0.61      0.68      0.64       350
#           2       0.95      0.93      0.94      2273
#
# avg / total       0.90      0.90      0.90      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 36.5807108879 seconds.
# stratified 5 fold CV 0.986302514579 0.00683117249784
#              precision    recall  f1-score   support
#
#           1       0.90      0.84      0.87       156
#           2       0.99      0.99      0.99      2763
#
# avg / total       0.99      0.99      0.99      2919

# %% [markdown]
# ## Gradient Boosting

# %%
#gradient boost 100
classifier = 'ensemble.GradientBoostingClassifier()'
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 17.8596830368 seconds.
# stratified 5 fold CV 0.821160939623 0.0411295113369
#              precision    recall  f1-score   support
#
#           1       0.70      0.37      0.49       115
#           2       0.84      0.95      0.89       394
#
# avg / total       0.81      0.82      0.80       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 10.4773581028 seconds.
# stratified 5 fold CV 0.81087431694 0.0708750542407
#              precision    recall  f1-score   support
#
#           1       0.75      0.79      0.77       120
#           2       0.86      0.82      0.84       182
#
# avg / total       0.81      0.81      0.81       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 65.1136770248 seconds.
# stratified 5 fold CV 0.966348436734 0.0209346550405
#              precision    recall  f1-score   support
#
#           1       0.85      0.80      0.82       187
#           2       0.98      0.98      0.98      1653
#
# avg / total       0.96      0.96      0.96      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 13.6462459564 seconds.
# stratified 5 fold CV 0.835268581629 0.0308915839126
#              precision    recall  f1-score   support
#
#           1       0.55      0.29      0.38        73
#           2       0.85      0.95      0.90       321
#
# avg / total       0.80      0.82      0.80       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 56.9465088844 seconds.
# stratified 5 fold CV 0.895906432749 0.0073040912262
#              precision    recall  f1-score   support
#
#           1       0.73      0.17      0.27       200
#           2       0.90      0.99      0.94      1510
#
# avg / total       0.88      0.90      0.86      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 16.5163981915 seconds.
# stratified 5 fold CV 0.818644510829 0.0348108956544
#              precision    recall  f1-score   support
#
#           1       0.77      0.75      0.76       202
#           2       0.84      0.85      0.85       316
#
# avg / total       0.81      0.81      0.81       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 12.1375899315 seconds.
# stratified 5 fold CV 0.866327160494 0.0316541500544
#              precision    recall  f1-score   support
#
#           1       0.55      0.36      0.43        59
#           2       0.90      0.95      0.92       345
#
# avg / total       0.85      0.86      0.85       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 30.0374939442 seconds.
# stratified 5 fold CV 0.888220551378 0.0660782016768
#              precision    recall  f1-score   support
#
#           1       0.89      0.94      0.91       568
#           2       0.90      0.82      0.86       380
#
# avg / total       0.89      0.89      0.89       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 30.3101530075 seconds.
# stratified 5 fold CV 0.805910079768 0.0115045255834
#              precision    recall  f1-score   support
#
#           1       0.49      0.26      0.34       190
#           2       0.84      0.93      0.89       794
#
# avg / total       0.77      0.80      0.78       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 32.4110918045 seconds.
# stratified 5 fold CV 0.948535092011 0.00667997932572
#              precision    recall  f1-score   support
#
#           1       0.05      0.03      0.04        34
#           2       0.97      0.98      0.97       957
#
# avg / total       0.93      0.95      0.94       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 23.9804558754 seconds.
# stratified 5 fold CV 0.912511900984 0.0547559062113
#              precision    recall  f1-score   support
#
#           1       0.49      0.39      0.44        61
#           2       0.94      0.96      0.95       623
#
# avg / total       0.90      0.91      0.90       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 29.8850960732 seconds.
# stratified 5 fold CV 0.912697466156 0.0275638103426
#              precision    recall  f1-score   support
#
#           1       0.85      0.86      0.85       266
#           2       0.94      0.94      0.94       628
#
# avg / total       0.91      0.91      0.91       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 92.5730340481 seconds.
# stratified 5 fold CV 0.907000363504 0.0631570539232
#              precision    recall  f1-score   support
#
#           1       0.65      0.64      0.65       350
#           2       0.94      0.95      0.95      2273
#
# avg / total       0.91      0.91      0.91      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 100.94836688 seconds.
# stratified 5 fold CV 0.984248303461 0.00719349840872
#              precision    recall  f1-score   support
#
#           1       0.88      0.82      0.85       156
#           2       0.99      0.99      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919

# %% [markdown]
# ## SVM

# %%
#1 vs all linear svm
classifier = "grid_search.GridSearchCV(svm.LinearSVC(),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 88.0731480122 seconds.
# stratified 5 fold CV 0.707493690546 0.0794806610694
#              precision    recall  f1-score   support
#
#           1       0.40      0.50      0.45       115
#           2       0.84      0.79      0.81       394
#
# avg / total       0.74      0.72      0.73       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 54.7562119961 seconds.
# stratified 5 fold CV 0.711420765027 0.0819909619512
#              precision    recall  f1-score   support
#
#           1       0.61      0.70      0.65       120
#           2       0.78      0.70      0.74       182
#
# avg / total       0.71      0.70      0.70       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 184.704161167 seconds.
# stratified 5 fold CV 0.939166942774 0.0257599854582
#              precision    recall  f1-score   support
#
#           1       0.70      0.74      0.72       187
#           2       0.97      0.96      0.97      1653
#
# avg / total       0.94      0.94      0.94      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 68.9046418667 seconds.
# stratified 5 fold CV 0.721111652061 0.100355237222
#              precision    recall  f1-score   support
#
#           1       0.34      0.56      0.42        73
#           2       0.88      0.75      0.81       321
#
# avg / total       0.78      0.71      0.74       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 349.101258993 seconds.
# stratified 5 fold CV 0.779532163743 0.212985956534
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-798c4902dada> in <module>()
#       1 #1 vs all linear svm
#       2 classifier = "grid_search.GridSearchCV(svm.LinearSVC(),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
# ----> 3 main(classifier)
#
# <ipython-input-3-2c1349458dbf> in main(classifier_obj)
#      32                 toc()
#      33                 print 'stratified 5 fold CV', scores.mean(), scores.std()
# ---> 34                 print classifier.ClassificationReport(labels, classifier.XValidatePredict(labels,values,folds=20, stratified=True))
#      35
#      36
#
# /Users/jyhung/Documents/CellProfiler-Analyst/cpa/generalclassifier.py in XValidatePredict(self, labels, values, folds, stratified)
#     185             CV = cross_validation.KFold(num_samples, folds)
#     186
# --> 187         predictions = cross_validation.cross_val_predict(self.classifier, X=values, y=labels, cv=CV, n_jobs=1)
#     188         return np.array(predictions)
#     189
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_predict(estimator, X, y, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1204                                                       train, test, verbose,
#    1205                                                       fit_params)
# -> 1206                             for train, test in cv)
#    1207     p = np.concatenate([p for p, _ in preds_blocks])
#    1208     locs = np.concatenate([loc for _, loc in preds_blocks])
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     657             self._iterating = True
#     658             for function, args, kwargs in iterable:
# --> 659                 self.dispatch(function, args, kwargs)
#     660
#     661             if pre_dispatch == "all" or n_jobs == 1:
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch(self, func, args, kwargs)
#     404         """
#     405         if self._pool is None:
# --> 406             job = ImmediateApply(func, args, kwargs)
#     407             index = len(self._jobs)
#     408             if not _verbosity_filter(index, self.verbose):
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, func, args, kwargs)
#     138         # Don't delay the application, to avoid keeping the input
#     139         # arguments in memory
# --> 140         self.results = func(*args, **kwargs)
#     141
#     142     def get(self):
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params)
#    1260         estimator.fit(X_train, **fit_params)
#    1261     else:
# -> 1262         estimator.fit(X_train, y_train, **fit_params)
#    1263     preds = estimator.predict(X_test)
#    1264     return preds, test
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     730
#     731         """
# --> 732         return self._fit(X, y, ParameterGrid(self.param_grid))
#     733
#     734
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     503                                     self.fit_params, return_parameters=True,
#     504                                     error_score=self.error_score)
# --> 505                 for parameters in parameter_iterable
#     506                 for train, test in cv)
#     507
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     657             self._iterating = True
#     658             for function, args, kwargs in iterable:
# --> 659                 self.dispatch(function, args, kwargs)
#     660
#     661             if pre_dispatch == "all" or n_jobs == 1:
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch(self, func, args, kwargs)
#     404         """
#     405         if self._pool is None:
# --> 406             job = ImmediateApply(func, args, kwargs)
#     407             index = len(self._jobs)
#     408             if not _verbosity_filter(index, self.verbose):
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, func, args, kwargs)
#     138         # Don't delay the application, to avoid keeping the input
#     139         # arguments in memory
# --> 140         self.results = func(*args, **kwargs)
#     141
#     142     def get(self):
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1457             estimator.fit(X_train, **fit_params)
#    1458         else:
# -> 1459             estimator.fit(X_train, y_train, **fit_params)
#    1460
#    1461     except Exception as e:
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/svm/classes.pyc in fit(self, X, y)
#     205             self.class_weight, self.penalty, self.dual, self.verbose,
#     206             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 207             self.loss
#     208             )
#     209
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon)
#     838         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     839         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 840         epsilon)
#     841     # Regarding rnd.randint(..) in the above signature:
#     842     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
#1 vs all linear svm, auto weights 
classifier = "grid_search.GridSearchCV(svm.LinearSVC(penalty='l2', class_weight='auto'),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 84.4147870541 seconds.
# stratified 5 fold CV 0.738827412153 0.0729213429824
#              precision    recall  f1-score   support
#
#           1       0.46      0.48      0.47       115
#           2       0.85      0.84      0.84       394
#
# avg / total       0.76      0.75      0.76       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 55.7725188732 seconds.
# stratified 5 fold CV 0.737595628415 0.100795693685
#              precision    recall  f1-score   support
#
#           1       0.62      0.62      0.62       120
#           2       0.75      0.75      0.75       182
#
# avg / total       0.70      0.70      0.70       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 164.990232944 seconds.
# stratified 5 fold CV 0.931016225649 0.030718158007
#              precision    recall  f1-score   support
#
#           1       0.67      0.79      0.73       187
#           2       0.98      0.96      0.97      1653
#
# avg / total       0.94      0.94      0.94      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 61.6789281368 seconds.
# stratified 5 fold CV 0.728541869523 0.0362291169269
#              precision    recall  f1-score   support
#
#           1       0.30      0.30      0.30        73
#           2       0.84      0.84      0.84       321
#
# avg / total       0.74      0.74      0.74       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 343.934546947 seconds.
# stratified 5 fold CV 0.766081871345 0.150316288178
#              precision    recall  f1-score   support
#
#           1       0.35      0.17      0.23       200
#           2       0.90      0.96      0.93      1510
#
# avg / total       0.83      0.87      0.85      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 84.9436597824 seconds.
# stratified 5 fold CV 0.764553860379 0.0179083047408
#              precision    recall  f1-score   support
#
#           1       0.75      0.57      0.65       202
#           2       0.76      0.88      0.82       316
#
# avg / total       0.76      0.76      0.75       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 41.3494989872 seconds.
# stratified 5 fold CV 0.836512345679 0.0564269452692
#              precision    recall  f1-score   support
#
#           1       0.44      0.61      0.51        59
#           2       0.93      0.87      0.90       345
#
# avg / total       0.86      0.83      0.84       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 154.856153965 seconds.
# stratified 5 fold CV 0.804873294347 0.0918492879374
#              precision    recall  f1-score   support
#
#           1       0.81      0.92      0.86       568
#           2       0.85      0.67      0.75       380
#
# avg / total       0.82      0.82      0.81       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 181.463462114 seconds.
# stratified 5 fold CV 0.796710867088 0.0197125814342
#              precision    recall  f1-score   support
#
#           1       0.40      0.29      0.33       190
#           2       0.84      0.89      0.87       794
#
# avg / total       0.75      0.78      0.76       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 66.3853139877 seconds.
# stratified 5 fold CV 0.927429615905 0.0434488322479
#              precision    recall  f1-score   support
#
#           1       0.03      0.18      0.06        34
#           2       0.97      0.82      0.89       957
#
# avg / total       0.93      0.80      0.86       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 62.625125885 seconds.
# stratified 5 fold CV 0.883313731713 0.0691339114311
#              precision    recall  f1-score   support
#
#           1       0.42      0.49      0.45        61
#           2       0.95      0.93      0.94       623
#
# avg / total       0.90      0.89      0.90       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 172.932801008 seconds.
# stratified 5 fold CV 0.711533209187 0.051191369137
#              precision    recall  f1-score   support
#
#           1       0.54      0.67      0.59       266
#           2       0.84      0.76      0.80       628
#
# avg / total       0.75      0.73      0.74       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 388.668385983 seconds.
# stratified 5 fold CV 0.870418756816 0.100464750218
#              precision    recall  f1-score   support
#
#           1       0.50      0.60      0.55       350
#           2       0.94      0.91      0.92      2273
#
# avg / total       0.88      0.87      0.87      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 191.879827976 seconds.
# stratified 5 fold CV 0.964418070801 0.0458747857593
#              precision    recall  f1-score   support
#
#           1       0.85      0.87      0.86       156
#           2       0.99      0.99      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919

# %%
#1 vs all linear svm, auto weights, no search
classifier = "svm.LinearSVC(penalty='l2', class_weight='auto')"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 1.77711701393 seconds.
# stratified 5 fold CV 0.774102116094 0.0427799151412
#              precision    recall  f1-score   support
#
#           1       0.36      0.49      0.41       115
#           2       0.83      0.75      0.79       394
#
# avg / total       0.73      0.69      0.70       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 1.03716421127 seconds.
# stratified 5 fold CV 0.688415300546 0.0533515265037
#              precision    recall  f1-score   support
#
#           1       0.63      0.69      0.66       120
#           2       0.78      0.73      0.76       182
#
# avg / total       0.72      0.72      0.72       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 3.76545786858 seconds.
# stratified 5 fold CV 0.915332008017 0.0635373404695
#              precision    recall  f1-score   support
#
#           1       0.40      0.84      0.55       187
#           2       0.98      0.86      0.92      1653
#
# avg / total       0.92      0.86      0.88      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 1.25537514687 seconds.
# stratified 5 fold CV 0.711524667316 0.0944603473566
#              precision    recall  f1-score   support
#
#           1       0.34      0.32      0.33        73
#           2       0.85      0.86      0.85       321
#
# avg / total       0.75      0.76      0.76       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 7.05440211296 seconds.
# stratified 5 fold CV 0.829239766082 0.112009296736
#              precision    recall  f1-score   support
#
#           1       0.33      0.23      0.27       200
#           2       0.90      0.94      0.92      1510
#
# avg / total       0.84      0.86      0.84      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 1.65936088562 seconds.
# stratified 5 fold CV 0.718564138127 0.0633161620517
#              precision    recall  f1-score   support
#
#           1       0.74      0.72      0.73       202
#           2       0.82      0.84      0.83       316
#
# avg / total       0.79      0.79      0.79       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 0.942795038223 seconds.
# stratified 5 fold CV 0.848981481481 0.0526919379907
#              precision    recall  f1-score   support
#
#           1       0.41      0.47      0.44        59
#           2       0.91      0.88      0.89       345
#
# avg / total       0.83      0.82      0.83       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 3.26893496513 seconds.
# stratified 5 fold CV 0.682283486494 0.152779038354
#              precision    recall  f1-score   support
#
#           1       0.79      0.82      0.80       568
#           2       0.71      0.68      0.70       380
#
# avg / total       0.76      0.76      0.76       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 3.75865602493 seconds.
# stratified 5 fold CV 0.684507407024 0.223012409903
#              precision    recall  f1-score   support
#
#           1       0.27      0.34      0.30       190
#           2       0.83      0.77      0.80       794
#
# avg / total       0.72      0.69      0.70       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 1.50455498695 seconds.
# stratified 5 fold CV 0.931495502431 0.0422486970666
#              precision    recall  f1-score   support
#
#           1       0.07      0.12      0.09        34
#           2       0.97      0.95      0.96       957
#
# avg / total       0.94      0.92      0.93       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 1.39651107788 seconds.
# stratified 5 fold CV 0.903614321006 0.0261871103093
#              precision    recall  f1-score   support
#
#           1       0.39      0.39      0.39        61
#           2       0.94      0.94      0.94       623
#
# avg / total       0.89      0.89      0.89       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 3.53269195557 seconds.
# stratified 5 fold CV 0.742699558513 0.0245814900439
#              precision    recall  f1-score   support
#
#           1       0.52      0.58      0.55       266
#           2       0.81      0.77      0.79       628
#
# avg / total       0.72      0.71      0.72       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 8.12456011772 seconds.
# stratified 5 fold CV 0.834519083969 0.0589095623939
#              precision    recall  f1-score   support
#
#           1       0.48      0.65      0.55       350
#           2       0.94      0.89      0.92      2273
#
# avg / total       0.88      0.86      0.87      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 3.88333296776 seconds.
# stratified 5 fold CV 0.985959461405 0.00736108055731
#              precision    recall  f1-score   support
#
#           1       0.82      0.85      0.84       156
#           2       0.99      0.99      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919

# %%
#1 vs all linear svm, l1 penalty, auto weights 
classifier = "grid_search.GridSearchCV(svm.LinearSVC(penalty='l1',dual=False, class_weight='auto'),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 80.5314002037 seconds.
# stratified 5 fold CV 0.766181324015 0.0743345558018
#              precision    recall  f1-score   support
#
#           1       0.53      0.54      0.54       115
#           2       0.87      0.86      0.86       394
#
# avg / total       0.79      0.79      0.79       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 46.1349279881 seconds.
# stratified 5 fold CV 0.764535519126 0.0591993722795
#              precision    recall  f1-score   support
#
#           1       0.68      0.79      0.73       120
#           2       0.85      0.75      0.80       182
#
# avg / total       0.78      0.77      0.77       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 351.477404833 seconds.
# stratified 5 fold CV 0.918538262077 0.0428188436378
#              precision    recall  f1-score   support
#
#           1       0.57      0.80      0.67       187
#           2       0.98      0.93      0.95      1653
#
# avg / total       0.93      0.92      0.92      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 65.9434688091 seconds.
# stratified 5 fold CV 0.769949691659 0.104069110182
#              precision    recall  f1-score   support
#
#           1       0.40      0.55      0.47        73
#           2       0.89      0.82      0.85       321
#
# avg / total       0.80      0.77      0.78       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 374.04403615 seconds.
# stratified 5 fold CV 0.83918128655 0.0392728266442
#              precision    recall  f1-score   support
#
#           1       0.37      0.49      0.42       200
#           2       0.93      0.89      0.91      1510
#
# avg / total       0.86      0.84      0.85      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 105.776283026 seconds.
# stratified 5 fold CV 0.751054624987 0.037851013988
#              precision    recall  f1-score   support
#
#           1       0.67      0.73      0.70       202
#           2       0.82      0.77      0.79       316
#
# avg / total       0.76      0.75      0.76       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 58.4520819187 seconds.
# stratified 5 fold CV 0.824135802469 0.0777974695825
#              precision    recall  f1-score   support
#
#           1       0.41      0.54      0.46        59
#           2       0.92      0.86      0.89       345
#
# avg / total       0.84      0.82      0.83       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 212.017135143 seconds.
# stratified 5 fold CV 0.856558061821 0.0620314587912
#              precision    recall  f1-score   support
#
#           1       0.86      0.88      0.87       568
#           2       0.82      0.79      0.81       380
#
# avg / total       0.85      0.85      0.85       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 207.595175028 seconds.
# stratified 5 fold CV 0.749880866052 0.0687684807682
#              precision    recall  f1-score   support
#
#           1       0.40      0.55      0.46       190
#           2       0.88      0.80      0.84       794
#
# avg / total       0.79      0.75      0.77       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 112.733893871 seconds.
# stratified 5 fold CV 0.909400228853 0.0720174460699
#              precision    recall  f1-score   support
#
#           1       0.09      0.18      0.12        34
#           2       0.97      0.93      0.95       957
#
# avg / total       0.94      0.91      0.92       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 84.5223488808 seconds.
# stratified 5 fold CV 0.913960865209 0.0606937697398
#              precision    recall  f1-score   support
#
#           1       0.51      0.67      0.58        61
#           2       0.97      0.94      0.95       623
#
# avg / total       0.93      0.91      0.92       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 194.754974127 seconds.
# stratified 5 fold CV 0.823129049582 0.0809997586785
#              precision    recall  f1-score   support
#
#           1       0.68      0.74      0.71       266
#           2       0.88      0.85      0.87       628
#
# avg / total       0.82      0.82      0.82       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 659.159919024 seconds.
# stratified 5 fold CV 0.895182115594 0.0798274767736
#              precision    recall  f1-score   support
#
#           1       0.57      0.81      0.67       350
#           2       0.97      0.91      0.94      2273
#
# avg / total       0.92      0.89      0.90      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 291.245784998 seconds.
# stratified 5 fold CV 0.980829506067 0.0118027000675
#              precision    recall  f1-score   support
#
#           1       0.80      0.85      0.83       156
#           2       0.99      0.99      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919

# %%
#1 vs 1 linear svm
classifier = "grid_search.GridSearchCV(svm.SVC(kernel='linear'),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 357.650186777 seconds.
# stratified 5 fold CV 0.738652688798 0.0299442555719
#              precision    recall  f1-score   support
#
#           1       0.43      0.50      0.46       115
#           2       0.85      0.81      0.83       394
#
# avg / total       0.75      0.74      0.74       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 82.8608181477 seconds.
# stratified 5 fold CV 0.675245901639 0.052542226811
#              precision    recall  f1-score   support
#
#           1       0.59      0.62      0.60       120
#           2       0.74      0.71      0.72       182
#
# avg / total       0.68      0.68      0.68       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 779.299878836 seconds.
# stratified 5 fold CV 0.922878772118 0.023972855571
#              precision    recall  f1-score   support
#
#           1       0.59      0.75      0.67       187
#           2       0.97      0.94      0.96      1653
#
# avg / total       0.93      0.92      0.93      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 128.965348005 seconds.
# stratified 5 fold CV 0.729182895164 0.102702567917
#              precision    recall  f1-score   support
#
#           1       0.33      0.47      0.39        73
#           2       0.87      0.79      0.83       321
#
# avg / total       0.77      0.73      0.74       394

# %%
#svm rbf
classifier = "grid_search.GridSearchCV(svm.SVC(),param_grid={'gamma': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1], 'C': [2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=-1)"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 28.1089689732 seconds.
# stratified 5 fold CV 0.774063288682 0.000893030479519
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00       115
#           2       0.77      1.00      0.87       394
#
# avg / total       0.60      0.77      0.68       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 11.5640640259 seconds.
# stratified 5 fold CV 0.605901639344 0.00889485899426
#              precision    recall  f1-score   support
#
#           1       1.00      0.01      0.02       120
#           2       0.60      1.00      0.75       182
#
# avg / total       0.76      0.61      0.46       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 346.586475849 seconds.
# stratified 5 fold CV 0.898371916947 0.00110919664361
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-64a9c824ae3f> in <module>()
#       1 #svm rbf
#       2 classifier = "grid_search.GridSearchCV(svm.SVC(),param_grid={'gamma': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1], 'C': [2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=-1)"
# ----> 3 main(classifier)
#
# <ipython-input-2-46c6b62bcbfd> in main(classifier_obj)
#      32                 toc()
#      33                 print 'stratified 5 fold CV', scores.mean(), scores.std()
# ---> 34                 print classifier.ClassificationReport(labels, classifier.XValidatePredict(labels,values,folds=5, stratified=True))
#      35
#      36
#
# /Users/jyhung/Documents/CellProfiler-Analyst/cpa/generalclassifier.pyc in XValidatePredict(self, labels, values, folds, stratified)
#     185             CV = cross_validation.KFold(num_samples, folds)
#     186
# --> 187         predictions = cross_validation.cross_val_predict(self.classifier, X=values, y=labels, cv=CV, n_jobs=1)
#     188         return np.array(predictions)
#     189
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_predict(estimator, X, y, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1204                                                       train, test, verbose,
#    1205                                                       fit_params)
# -> 1206                             for train, test in cv)
#    1207     p = np.concatenate([p for p, _ in preds_blocks])
#    1208     locs = np.concatenate([loc for _, loc in preds_blocks])
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     657             self._iterating = True
#     658             for function, args, kwargs in iterable:
# --> 659                 self.dispatch(function, args, kwargs)
#     660
#     661             if pre_dispatch == "all" or n_jobs == 1:
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch(self, func, args, kwargs)
#     404         """
#     405         if self._pool is None:
# --> 406             job = ImmediateApply(func, args, kwargs)
#     407             index = len(self._jobs)
#     408             if not _verbosity_filter(index, self.verbose):
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, func, args, kwargs)
#     138         # Don't delay the application, to avoid keeping the input
#     139         # arguments in memory
# --> 140         self.results = func(*args, **kwargs)
#     141
#     142     def get(self):
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params)
#    1260         estimator.fit(X_train, **fit_params)
#    1261     else:
# -> 1262         estimator.fit(X_train, y_train, **fit_params)
#    1263     preds = estimator.predict(X_test)
#    1264     return preds, test
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     730
#     731         """
# --> 732         return self._fit(X, y, ParameterGrid(self.param_grid))
#     733
#     734
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     503                                     self.fit_params, return_parameters=True,
#     504                                     error_score=self.error_score)
# --> 505                 for parameters in parameter_iterable
#     506                 for train, test in cv)
#     507
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     664                 # consumption.
#     665                 self._iterating = False
# --> 666             self.retrieve()
#     667             # Make sure that we get a last message telling us we are done
#     668             elapsed_time = time.time() - self._start_time
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     530                             # We can now allow subprocesses again
#     531                             os.environ.pop('__JOBLIB_SPAWNED_PARALLEL__', 0)
# --> 532                         raise exception
#     533                     elif isinstance(exception, TransportableException):
#     534                         # Capture exception to add information on the local
#
# KeyboardInterrupt:

# %%
#svm rbf, class weight auto
classifier = "grid_search.GridSearchCV(svm.SVC(class_weight='auto'),param_grid={'gamma': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1], 'C': [2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=-1)"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 27.4059941769 seconds.
# stratified 5 fold CV 0.781906425937 0.0100036926712
#              precision    recall  f1-score   support
#
#           1       1.00      0.03      0.07       115
#           2       0.78      1.00      0.88       394
#
# avg / total       0.83      0.78      0.69       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 10.8943209648 seconds.
# stratified 5 fold CV 0.632131147541 0.0396924483945
#              precision    recall  f1-score   support
#
#           1       1.00      0.07      0.14       120
#           2       0.62      1.00      0.77       182
#
# avg / total       0.77      0.63      0.52       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 315.378823042 seconds.
# stratified 5 fold CV 0.901641671715 0.00475062923119
#              precision    recall  f1-score   support
#
#           1       1.00      0.03      0.06       187
#           2       0.90      1.00      0.95      1653
#
# avg / total       0.91      0.90      0.86      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 16.6276390553 seconds.
# stratified 5 fold CV 0.814755761117 0.00477984345829
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        73
#           2       0.81      1.00      0.90       321
#
# avg / total       0.66      0.81      0.73       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-d1b760f46ff5> in <module>()
#       1 #svm rbf, class weight auto
#       2 classifier = "grid_search.GridSearchCV(svm.SVC(class_weight='auto'),param_grid={'gamma': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1], 'C': [2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=-1)"
# ----> 3 main(classifier)
#
# <ipython-input-2-46c6b62bcbfd> in main(classifier_obj)
#      29                 tic()
#      30                 print 'Scoring cells 1 ...'
# ---> 31                 scores = classifier.XValidate(labels, values, folds=5, stratified=True)
#      32                 toc()
#      33                 print 'stratified 5 fold CV', scores.mean(), scores.std()
#
# /Users/jyhung/Documents/CellProfiler-Analyst/cpa/generalclassifier.pyc in XValidate(self, labels, values, folds, stratified, scoring)
#     140             CV = cross_validation.KFold(num_samples, folds)
#     141         #scores = cross_validation.cross_val_score(self.classifier, scoring=scoring, X=values, y=labels, cv=CV, n_jobs=-1, verbose=1)
# --> 142         scores = cross_validation.cross_val_score(self.classifier, X=values, y=labels, cv=folds, n_jobs=1)
#     143
#     144         return np.array(scores)
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1359                                               train, test, verbose, None,
#    1360                                               fit_params)
# -> 1361                       for train, test in cv)
#    1362     return np.array(scores)[:, 0]
#    1363
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     657             self._iterating = True
#     658             for function, args, kwargs in iterable:
# --> 659                 self.dispatch(function, args, kwargs)
#     660
#     661             if pre_dispatch == "all" or n_jobs == 1:
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch(self, func, args, kwargs)
#     404         """
#     405         if self._pool is None:
# --> 406             job = ImmediateApply(func, args, kwargs)
#     407             index = len(self._jobs)
#     408             if not _verbosity_filter(index, self.verbose):
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, func, args, kwargs)
#     138         # Don't delay the application, to avoid keeping the input
#     139         # arguments in memory
# --> 140         self.results = func(*args, **kwargs)
#     141
#     142     def get(self):
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1457             estimator.fit(X_train, **fit_params)
#    1458         else:
# -> 1459             estimator.fit(X_train, y_train, **fit_params)
#    1460
#    1461     except Exception as e:
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     730
#     731         """
# --> 732         return self._fit(X, y, ParameterGrid(self.param_grid))
#     733
#     734
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     503                                     self.fit_params, return_parameters=True,
#     504                                     error_score=self.error_score)
# --> 505                 for parameters in parameter_iterable
#     506                 for train, test in cv)
#     507
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     664                 # consumption.
#     665                 self._iterating = False
# --> 666             self.retrieve()
#     667             # Make sure that we get a last message telling us we are done
#     668             elapsed_time = time.time() - self._start_time
#
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     530                             # We can now allow subprocesses again
#     531                             os.environ.pop('__JOBLIB_SPAWNED_PARALLEL__', 0)
# --> 532                         raise exception
#     533                     elif isinstance(exception, TransportableException):
#     534                         # Capture exception to add information on the local
#
# KeyboardInterrupt:

# %% [markdown]
# ## LDA

# %%
classifier = "lda.LDA()"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 0.418704032898 seconds.
# stratified 5 fold CV 0.62686856921 0.0790804157202
#              precision    recall  f1-score   support
#
#           1       0.31      0.55      0.40       115
#           2       0.83      0.65      0.73       394
#
# avg / total       0.71      0.63      0.65       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 0.186514854431 seconds.
# stratified 5 fold CV 0.695136612022 0.0742358123566
#              precision    recall  f1-score   support
#
#           1       0.60      0.72      0.65       120
#           2       0.79      0.68      0.73       182
#
# avg / total       0.71      0.70      0.70       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 1.2811319828 seconds.
# stratified 5 fold CV 0.905567129596 0.0852560247984
#              precision    recall  f1-score   support
#
#           1       0.52      0.81      0.63       187
#           2       0.98      0.92      0.95      1653
#
# avg / total       0.93      0.91      0.91      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 0.298842906952 seconds.
# stratified 5 fold CV 0.66329438494 0.0952303696454
#              precision    recall  f1-score   support
#
#           1       0.29      0.59      0.39        73
#           2       0.88      0.68      0.77       321
#
# avg / total       0.77      0.66      0.70       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 1.21162295341 seconds.
# stratified 5 fold CV 0.85730994152 0.0309112872197
#              precision    recall  f1-score   support
#
#           1       0.41      0.52      0.46       200
#           2       0.93      0.90      0.92      1510
#
# avg / total       0.87      0.86      0.86      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 0.424867153168 seconds.
# stratified 5 fold CV 0.614174757282 0.0709936478143
#              precision    recall  f1-score   support
#
#           1       0.50      0.61      0.55       202
#           2       0.71      0.62      0.66       316
#
# avg / total       0.63      0.61      0.62       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 0.279524087906 seconds.
# stratified 5 fold CV 0.757283950617 0.0764858407072
#              precision    recall  f1-score   support
#
#           1       0.31      0.53      0.39        59
#           2       0.91      0.80      0.85       345
#
# avg / total       0.82      0.76      0.78       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 0.83882689476 seconds.
# stratified 5 fold CV 0.733110554163 0.0314833602933
#              precision    recall  f1-score   support
#
#           1       0.77      0.80      0.78       568
#           2       0.68      0.63      0.66       380
#
# avg / total       0.73      0.73      0.73       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 0.835168123245 seconds.
# stratified 5 fold CV 0.620843261162 0.0552209121572
#              precision    recall  f1-score   support
#
#           1       0.25      0.47      0.33       190
#           2       0.84      0.66      0.74       794
#
# avg / total       0.72      0.62      0.66       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 0.865505933762 seconds.
# stratified 5 fold CV 0.819408120951 0.0381802510548
#              precision    recall  f1-score   support
#
#           1       0.03      0.12      0.04        34
#           2       0.96      0.84      0.90       957
#
# avg / total       0.93      0.82      0.87       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 0.633265972137 seconds.
# stratified 5 fold CV 0.674144218144 0.0476614689354
#              precision    recall  f1-score   support
#
#           1       0.14      0.54      0.23        61
#           2       0.94      0.69      0.79       623
#
# avg / total       0.87      0.67      0.74       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 0.802158117294 seconds.
# stratified 5 fold CV 0.680021969745 0.0734265499994
#              precision    recall  f1-score   support
#
#           1       0.47      0.70      0.57       266
#           2       0.84      0.67      0.75       628
#
# avg / total       0.73      0.68      0.69       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 1.81517195702 seconds.
# stratified 5 fold CV 0.872707379135 0.0933487676033
#              precision    recall  f1-score   support
#
#           1       0.52      0.74      0.61       350
#           2       0.96      0.89      0.92      2273
#
# avg / total       0.90      0.87      0.88      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 1.85517692566 seconds.
# stratified 5 fold CV 0.979107191163 0.0145347309418
#              precision    recall  f1-score   support
#
#           1       0.75      0.90      0.82       156
#           2       0.99      0.98      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/lda.py:371: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %% [markdown]
# ## Random Forest

# %%
#random forest 100
classifier = "ensemble.RandomForestClassifier(n_estimators=100)"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 1.72977089882 seconds.
# stratified 5 fold CV 0.836944282664 0.0219353745913
#              precision    recall  f1-score   support
#
#           1       0.89      0.37      0.52       115
#           2       0.84      0.99      0.91       394
#
# avg / total       0.85      0.85      0.82       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 0.937800884247 seconds.
# stratified 5 fold CV 0.827322404372 0.0831188676262
#              precision    recall  f1-score   support
#
#           1       0.74      0.75      0.75       120
#           2       0.83      0.83      0.83       182
#
# avg / total       0.80      0.80      0.80       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 7.35504484177 seconds.
# stratified 5 fold CV 0.970130651816 0.0117144102093
#              precision    recall  f1-score   support
#
#           1       0.95      0.75      0.84       187
#           2       0.97      1.00      0.98      1653
#
# avg / total       0.97      0.97      0.97      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 1.29332995415 seconds.
# stratified 5 fold CV 0.840170399221 0.022971681529
#              precision    recall  f1-score   support
#
#           1       0.83      0.21      0.33        73
#           2       0.85      0.99      0.91       321
#
# avg / total       0.84      0.85      0.80       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 11.7678599358 seconds.
# stratified 5 fold CV 0.888888888889 0.00554785554416
#              precision    recall  f1-score   support
#
#           1       1.00      0.04      0.09       200
#           2       0.89      1.00      0.94      1510
#
# avg / total       0.90      0.89      0.84      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 1.82513999939 seconds.
# stratified 5 fold CV 0.799523631708 0.0529303427119
#              precision    recall  f1-score   support
#
#           1       0.71      0.76      0.74       202
#           2       0.84      0.81      0.82       316
#
# avg / total       0.79      0.79      0.79       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 1.46215701103 seconds.
# stratified 5 fold CV 0.876265432099 0.0132796415518
#              precision    recall  f1-score   support
#
#           1       0.75      0.20      0.32        59
#           2       0.88      0.99      0.93       345
#
# avg / total       0.86      0.87      0.84       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 5.00091910362 seconds.
# stratified 5 fold CV 0.87977722083 0.0670052783579
#              precision    recall  f1-score   support
#
#           1       0.88      0.92      0.90       568
#           2       0.87      0.81      0.84       380
#
# avg / total       0.88      0.88      0.88       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 4.70679998398 seconds.
# stratified 5 fold CV 0.816057184295 0.00983082946144
#              precision    recall  f1-score   support
#
#           1       0.68      0.09      0.16       190
#           2       0.82      0.99      0.90       794
#
# avg / total       0.79      0.82      0.75       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 5.10959100723 seconds.
# stratified 5 fold CV 0.965696863541 0.00192478228352
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        34
#           2       0.97      1.00      0.98       957
#
# avg / total       0.93      0.96      0.95       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 1.70531201363 seconds.
# stratified 5 fold CV 0.924052899484 0.0205628216799
#              precision    recall  f1-score   support
#
#           1       0.76      0.31      0.44        61
#           2       0.94      0.99      0.96       623
#
# avg / total       0.92      0.93      0.92       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 3.68270206451 seconds.
# stratified 5 fold CV 0.890300880882 0.0365219289309
#              precision    recall  f1-score   support
#
#           1       0.84      0.79      0.82       266
#           2       0.91      0.94      0.93       628
#
# avg / total       0.89      0.89      0.89       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 10.3997619152 seconds.
# stratified 5 fold CV 0.911941112323 0.0337683156388
#              precision    recall  f1-score   support
#
#           1       0.73      0.55      0.63       350
#           2       0.93      0.97      0.95      2273
#
# avg / total       0.91      0.91      0.91      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 8.51984620094 seconds.
# stratified 5 fold CV 0.982871986863 0.00389760847779
#              precision    recall  f1-score   support
#
#           1       0.93      0.72      0.81       156
#           2       0.98      1.00      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919

# %%
#random forest 100, class weights auto
classifier = "ensemble.RandomForestClassifier(n_estimators=100, class_weight='auto')"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 1.68912696838 seconds.
# stratified 5 fold CV 0.842787808193 0.0168320974118
#              precision    recall  f1-score   support
#
#           1       0.88      0.38      0.53       115
#           2       0.85      0.98      0.91       394
#
# avg / total       0.85      0.85      0.82       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 0.984733819962 seconds.
# stratified 5 fold CV 0.817540983607 0.0747417143738
#              precision    recall  f1-score   support
#
#           1       0.76      0.80      0.78       120
#           2       0.86      0.83      0.85       182
#
# avg / total       0.82      0.82      0.82       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 5.43034505844 seconds.
# stratified 5 fold CV 0.972303116098 0.0101726215612
#              precision    recall  f1-score   support
#
#           1       0.95      0.78      0.86       187
#           2       0.98      1.00      0.99      1653
#
# avg / total       0.97      0.97      0.97      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 1.44434714317 seconds.
# stratified 5 fold CV 0.860552580331 0.0321796624851
#              precision    recall  f1-score   support
#
#           1       0.86      0.33      0.48        73
#           2       0.87      0.99      0.92       321
#
# avg / total       0.86      0.87      0.84       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 7.41966605186 seconds.
# stratified 5 fold CV 0.888304093567 0.00535973765492
#              precision    recall  f1-score   support
#
#           1       1.00      0.06      0.10       200
#           2       0.89      1.00      0.94      1510
#
# avg / total       0.90      0.89      0.84      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 2.08705210686 seconds.
# stratified 5 fold CV 0.784063622462 0.0564270283541
#              precision    recall  f1-score   support
#
#           1       0.73      0.72      0.72       202
#           2       0.82      0.83      0.82       316
#
# avg / total       0.79      0.79      0.79       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 1.15275382996 seconds.
# stratified 5 fold CV 0.871296296296 0.00582344514324
#              precision    recall  f1-score   support
#
#           1       0.70      0.12      0.20        59
#           2       0.87      0.99      0.93       345
#
# avg / total       0.84      0.86      0.82       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 4.68213200569 seconds.
# stratified 5 fold CV 0.876613756614 0.0666822714797
#              precision    recall  f1-score   support
#
#           1       0.87      0.92      0.90       568
#           2       0.87      0.80      0.83       380
#
# avg / total       0.87      0.87      0.87       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 4.23302602768 seconds.
# stratified 5 fold CV 0.827245415933 0.008300156208
#              precision    recall  f1-score   support
#
#           1       0.76      0.16      0.27       190
#           2       0.83      0.99      0.90       794
#
# avg / total       0.82      0.83      0.78       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 2.45053505898 seconds.
# stratified 5 fold CV 0.965696863541 0.00192478228352
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        34
#           2       0.97      1.00      0.98       957
#
# avg / total       0.93      0.97      0.95       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 1.58829402924 seconds.
# stratified 5 fold CV 0.929977411466 0.0437241902874
#              precision    recall  f1-score   support
#
#           1       0.78      0.46      0.58        61
#           2       0.95      0.99      0.97       623
#
# avg / total       0.93      0.94      0.93       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 4.13515305519 seconds.
# stratified 5 fold CV 0.89819087872 0.0377024329856
#              precision    recall  f1-score   support
#
#           1       0.87      0.79      0.83       266
#           2       0.91      0.95      0.93       628
#
# avg / total       0.90      0.90      0.90       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 14.013725996 seconds.
# stratified 5 fold CV 0.909654671029 0.0362745421117
#              precision    recall  f1-score   support
#
#           1       0.72      0.56      0.63       350
#           2       0.93      0.97      0.95      2273
#
# avg / total       0.91      0.91      0.91      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 6.27810811996 seconds.
# stratified 5 fold CV 0.98424654321 0.0063319204123
#              precision    recall  f1-score   support
#
#           1       0.93      0.81      0.86       156
#           2       0.99      1.00      0.99      2763
#
# avg / total       0.99      0.99      0.99      2919
# /Users/jyhung/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:958: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#random forest 1000
classifier = "ensemble.RandomForestClassifier(n_estimators=1000)"
main(classifier)

# %% [markdown]
# ## Naive Bayes

# %%
classifier = "naive_bayes.GaussianNB()"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0246541500092 seconds.
# stratified 5 fold CV 0.597185012619 0.0685946265532
#              precision    recall  f1-score   support
#
#           1       0.34      0.87      0.49       115
#           2       0.93      0.52      0.67       394
#
# avg / total       0.80      0.60      0.63       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0216488838196 seconds.
# stratified 5 fold CV 0.727704918033 0.136536547457
#              precision    recall  f1-score   support
#
#           1       0.61      0.88      0.72       120
#           2       0.88      0.63      0.74       182
#
# avg / total       0.78      0.73      0.73       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 0.101501941681 seconds.
# stratified 5 fold CV 0.52404855286 0.208300586246
#              precision    recall  f1-score   support
#
#           1       0.17      0.91      0.28       187
#           2       0.98      0.48      0.64      1653
#
# avg / total       0.90      0.52      0.61      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0305049419403 seconds.
# stratified 5 fold CV 0.557082116196 0.137592169993
#              precision    recall  f1-score   support
#
#           1       0.28      0.88      0.42        73
#           2       0.95      0.48      0.64       321
#
# avg / total       0.82      0.56      0.60       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 0.100208044052 seconds.
# stratified 5 fold CV 0.418128654971 0.0853680997711
#              precision    recall  f1-score   support
#
#           1       0.14      0.76      0.23       200
#           2       0.92      0.37      0.53      1510
#
# avg / total       0.83      0.42      0.50      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0294930934906 seconds.
# stratified 5 fold CV 0.615818485721 0.0155381778992
#              precision    recall  f1-score   support
#
#           1       0.50      0.92      0.65       202
#           2       0.89      0.42      0.57       316
#
# avg / total       0.74      0.62      0.60       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0299508571625 seconds.
# stratified 5 fold CV 0.477222222222 0.152620807252
#              precision    recall  f1-score   support
#
#           1       0.21      0.93      0.34        59
#           2       0.97      0.40      0.57       345
#
# avg / total       0.86      0.48      0.53       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0535500049591 seconds.
# stratified 5 fold CV 0.786856028961 0.0939984362796
#              precision    recall  f1-score   support
#
#           1       0.78      0.89      0.83       568
#           2       0.80      0.63      0.70       380
#
# avg / total       0.79      0.79      0.78       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0615150928497 seconds.
# stratified 5 fold CV 0.441862633378 0.150972338183
#              precision    recall  f1-score   support
#
#           1       0.25      0.93      0.39       190
#           2       0.95      0.33      0.49       794
#
# avg / total       0.81      0.44      0.47       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0691640377045 seconds.
# stratified 5 fold CV 0.86286323171 0.101596340714
#              precision    recall  f1-score   support
#
#           1       0.07      0.26      0.12        34
#           2       0.97      0.88      0.93       957
#
# avg / total       0.94      0.86      0.90       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0459191799164 seconds.
# stratified 5 fold CV 0.810200776598 0.110267558115
#              precision    recall  f1-score   support
#
#           1       0.31      0.90      0.46        61
#           2       0.99      0.80      0.88       623
#
# avg / total       0.93      0.81      0.85       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0597839355469 seconds.
# stratified 5 fold CV 0.707604879376 0.153148781191
#              precision    recall  f1-score   support
#
#           1       0.51      0.88      0.64       266
#           2       0.92      0.64      0.75       628
#
# avg / total       0.80      0.71      0.72       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 0.13446688652 seconds.
# stratified 5 fold CV 0.691855325336 0.232254127137
#              precision    recall  f1-score   support
#
#           1       0.29      0.94      0.45       350
#           2       0.99      0.65      0.79      2273
#
# avg / total       0.89      0.69      0.74      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 0.147752046585 seconds.
# stratified 5 fold CV 0.932915888712 0.0511476043683
#              precision    recall  f1-score   support
#
#           1       0.44      0.91      0.59       156
#           2       0.99      0.93      0.96      2763
#
# avg / total       0.96      0.93      0.94      2919

# %% [markdown]
# ## Logistic Regression

# %%
#logistic regression 1 vs all, no search
classifier = "linear_model.LogisticRegression(penalty='l2',solver='liblinear', multi_class='ovr', class_weight=None)" 
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 2.95930504799 seconds.
# stratified 5 fold CV 0.750495049505 0.0252061835998
#              precision    recall  f1-score   support
#
#           1       0.46      0.55      0.50       115
#           2       0.86      0.81      0.83       394
#
# avg / total       0.77      0.75      0.76       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 1.21097803116 seconds.
# stratified 5 fold CV 0.708306010929 0.0456860014218
#              precision    recall  f1-score   support
#
#           1       0.62      0.67      0.65       120
#           2       0.77      0.74      0.75       182
#
# avg / total       0.71      0.71      0.71       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 11.2295789719 seconds.
# stratified 5 fold CV 0.923981953968 0.0349920292436
#              precision    recall  f1-score   support
#
#           1       0.60      0.75      0.67       187
#           2       0.97      0.94      0.96      1653
#
# avg / total       0.93      0.92      0.93      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 1.4298491478 seconds.
# stratified 5 fold CV 0.726747809153 0.10613156712
#              precision    recall  f1-score   support
#
#           1       0.32      0.42      0.36        73
#           2       0.86      0.79      0.83       321
#
# avg / total       0.76      0.73      0.74       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 15.1456301212 seconds.
# stratified 5 fold CV 0.870175438596 0.0143959457603
#              precision    recall  f1-score   support
#
#           1       0.44      0.38      0.40       200
#           2       0.92      0.94      0.93      1510
#
# avg / total       0.86      0.87      0.87      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 3.03323912621 seconds.
# stratified 5 fold CV 0.74511735837 0.0484060043232
#              precision    recall  f1-score   support
#
#           1       0.67      0.69      0.68       202
#           2       0.80      0.78      0.79       316
#
# avg / total       0.75      0.75      0.75       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 0.961652994156 seconds.
# stratified 5 fold CV 0.819197530864 0.0586310581131
#              precision    recall  f1-score   support
#
#           1       0.40      0.46      0.43        59
#           2       0.90      0.88      0.89       345
#
# avg / total       0.83      0.82      0.82       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 5.72343397141 seconds.
# stratified 5 fold CV 0.851272626009 0.056031151948
#              precision    recall  f1-score   support
#
#           1       0.88      0.87      0.88       568
#           2       0.81      0.82      0.82       380
#
# avg / total       0.85      0.85      0.85       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 16.1219058037 seconds.
# stratified 5 fold CV 0.754951828447 0.0700943160405
#              precision    recall  f1-score   support
#
#           1       0.38      0.41      0.39       190
#           2       0.86      0.84      0.85       794
#
# avg / total       0.76      0.76      0.76       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 3.93623685837 seconds.
# stratified 5 fold CV 0.912384694327 0.0600559282211
#              precision    recall  f1-score   support
#
#           1       0.08      0.15      0.10        34
#           2       0.97      0.94      0.95       957
#
# avg / total       0.94      0.91      0.92       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 1.45151686668 seconds.
# stratified 5 fold CV 0.897774127106 0.0493774316059
#              precision    recall  f1-score   support
#
#           1       0.45      0.61      0.51        61
#           2       0.96      0.93      0.94       623
#
# avg / total       0.91      0.90      0.90       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 10.0870349407 seconds.
# stratified 5 fold CV 0.810844544878 0.0666831967744
#              precision    recall  f1-score   support
#
#           1       0.67      0.71      0.69       266
#           2       0.88      0.85      0.86       628
#
# avg / total       0.81      0.81      0.81       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 33.6145009995 seconds.
# stratified 5 fold CV 0.903950563431 0.059013431451
#              precision    recall  f1-score   support
#
#           1       0.63      0.69      0.66       350
#           2       0.95      0.94      0.94      2273
#
# avg / total       0.91      0.90      0.91      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 5.64284801483 seconds.
# stratified 5 fold CV 0.981507398578 0.00998933914984
#              precision    recall  f1-score   support
#
#           1       0.82      0.84      0.83       156
#           2       0.99      0.99      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919

# %%
#logistic regression 1 vs all class weight auto
classifier = "grid_search.GridSearchCV(linear_model.LogisticRegression(penalty='l2',solver='liblinear', multi_class='ovr', class_weight='auto'),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)" 
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 97.8326058388 seconds.
# stratified 5 fold CV 0.746456998641 0.0387391250179
#              precision    recall  f1-score   support
#
#           1       0.45      0.59      0.51       115
#           2       0.87      0.79      0.83       394
#
# avg / total       0.78      0.75      0.76       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 40.0054600239 seconds.
# stratified 5 fold CV 0.714918032787 0.0477426787377
#              precision    recall  f1-score   support
#
#           1       0.62      0.72      0.67       120
#           2       0.79      0.71      0.75       182
#
# avg / total       0.73      0.72      0.72       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 420.642338991 seconds.
# stratified 5 fold CV 0.906611181101 0.0487009296926
#              precision    recall  f1-score   support
#
#           1       0.53      0.78      0.63       187
#           2       0.97      0.92      0.95      1653
#
# avg / total       0.93      0.91      0.91      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 43.5190758705 seconds.
# stratified 5 fold CV 0.714024667316 0.0916320982188
#              precision    recall  f1-score   support
#
#           1       0.31      0.47      0.38        73
#           2       0.86      0.77      0.81       321
#
# avg / total       0.76      0.71      0.73       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 1108.03229308 seconds.
# stratified 5 fold CV 0.802339181287 0.0404566796642
#              precision    recall  f1-score   support
#
#           1       0.29      0.48      0.36       200
#           2       0.93      0.84      0.88      1510
#
# avg / total       0.85      0.80      0.82      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 99.1551969051 seconds.
# stratified 5 fold CV 0.75092428607 0.0441989204957
#              precision    recall  f1-score   support
#
#           1       0.67      0.72      0.69       202
#           2       0.81      0.77      0.79       316
#
# avg / total       0.76      0.75      0.75       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 36.5204701424 seconds.
# stratified 5 fold CV 0.814197530864 0.0681924171834
#              precision    recall  f1-score   support
#
#           1       0.39      0.47      0.43        59
#           2       0.91      0.87      0.89       345
#
# avg / total       0.83      0.81      0.82       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 220.98385191 seconds.
# stratified 5 fold CV 0.851255917572 0.0502354697877
#              precision    recall  f1-score   support
#
#           1       0.88      0.87      0.87       568
#           2       0.81      0.83      0.82       380
#
# avg / total       0.85      0.85      0.85       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 559.917013884 seconds.
# stratified 5 fold CV 0.727488863566 0.0829213403
#              precision    recall  f1-score   support
#
#           1       0.36      0.52      0.42       190
#           2       0.87      0.78      0.82       794
#
# avg / total       0.77      0.73      0.74       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 133.203463078 seconds.
# stratified 5 fold CV 0.893253479622 0.0744171422845
#              precision    recall  f1-score   support
#
#           1       0.09      0.24      0.13        34
#           2       0.97      0.92      0.94       957
#
# avg / total       0.94      0.89      0.92       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 51.6930780411 seconds.
# stratified 5 fold CV 0.884688178667 0.0650198221453
#              precision    recall  f1-score   support
#
#           1       0.41      0.66      0.50        61
#           2       0.96      0.91      0.93       623
#
# avg / total       0.91      0.88      0.90       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 312.539541006 seconds.
# stratified 5 fold CV 0.810857099017 0.0666639589908
#              precision    recall  f1-score   support
#
#           1       0.66      0.74      0.70       266
#           2       0.88      0.84      0.86       628
#
# avg / total       0.82      0.81      0.81       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 1372.890558 seconds.
# stratified 5 fold CV 0.881089058524 0.099048743615
#              precision    recall  f1-score   support
#
#           1       0.54      0.79      0.64       350
#           2       0.97      0.89      0.93      2273
#
# avg / total       0.91      0.88      0.89      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 276.006453991 seconds.
# stratified 5 fold CV 0.982882546361 0.0127944957422
#              precision    recall  f1-score   support
#
#           1       0.80      0.90      0.85       156
#           2       0.99      0.99      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919

# %%
#logistic regression 1 vs all class weight auto, no search
classifier = "linear_model.LogisticRegression(penalty='l2',solver='liblinear', multi_class='ovr', class_weight='auto')" 
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 3.23333287239 seconds.
# stratified 5 fold CV 0.734711706465 0.0309570399496
#              precision    recall  f1-score   support
#
#           1       0.43      0.57      0.49       115
#           2       0.86      0.78      0.82       394
#
# avg / total       0.76      0.73      0.75       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 0.947407960892 seconds.
# stratified 5 fold CV 0.708360655738 0.0360521584588
#              precision    recall  f1-score   support
#
#           1       0.62      0.67      0.65       120
#           2       0.77      0.74      0.75       182
#
# avg / total       0.71      0.71      0.71       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 13.0575060844 seconds.
# stratified 5 fold CV 0.900638819621 0.0455897228787
#              precision    recall  f1-score   support
#
#           1       0.51      0.77      0.61       187
#           2       0.97      0.92      0.94      1653
#
# avg / total       0.93      0.90      0.91      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 1.60491704941 seconds.
# stratified 5 fold CV 0.71658876988 0.0967129089757
#              precision    recall  f1-score   support
#
#           1       0.31      0.45      0.37        73
#           2       0.86      0.78      0.82       321
#
# avg / total       0.76      0.72      0.73       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 36.3981001377 seconds.
# stratified 5 fold CV 0.79649122807 0.0417053785489
#              precision    recall  f1-score   support
#
#           1       0.29      0.51      0.37       200
#           2       0.93      0.84      0.88      1510
#
# avg / total       0.85      0.80      0.82      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 3.52395582199 seconds.
# stratified 5 fold CV 0.739329456951 0.0489632177518
#              precision    recall  f1-score   support
#
#           1       0.66      0.69      0.67       202
#           2       0.79      0.77      0.78       316
#
# avg / total       0.74      0.74      0.74       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 1.2259888649 seconds.
# stratified 5 fold CV 0.816697530864 0.0659864994298
#              precision    recall  f1-score   support
#
#           1       0.39      0.47      0.43        59
#           2       0.91      0.88      0.89       345
#
# avg / total       0.83      0.82      0.82       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 6.78435397148 seconds.
# stratified 5 fold CV 0.851272626009 0.0555345687529
#              precision    recall  f1-score   support
#
#           1       0.88      0.87      0.88       568
#           2       0.81      0.82      0.82       380
#
# avg / total       0.85      0.85      0.85       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 18.8213369846 seconds.
# stratified 5 fold CV 0.733585413861 0.0893778004197
#              precision    recall  f1-score   support
#
#           1       0.37      0.53      0.43       190
#           2       0.87      0.78      0.83       794
#
# avg / total       0.78      0.73      0.75       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 5.55345201492 seconds.
# stratified 5 fold CV 0.887228456284 0.0842165057799
#              precision    recall  f1-score   support
#
#           1       0.09      0.24      0.12        34
#           2       0.97      0.91      0.94       957
#
# avg / total       0.94      0.89      0.91       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 1.56919693947 seconds.
# stratified 5 fold CV 0.891977336793 0.050373679459
#              precision    recall  f1-score   support
#
#           1       0.43      0.64      0.51        61
#           2       0.96      0.92      0.94       623
#
# avg / total       0.92      0.89      0.90       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 8.87298607826 seconds.
# stratified 5 fold CV 0.805226637095 0.068713131213
#              precision    recall  f1-score   support
#
#           1       0.66      0.73      0.69       266
#           2       0.88      0.84      0.86       628
#
# avg / total       0.81      0.81      0.81       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 33.0307610035 seconds.
# stratified 5 fold CV 0.887182842603 0.0809693252641
#              precision    recall  f1-score   support
#
#           1       0.56      0.77      0.65       350
#           2       0.96      0.90      0.93      2273
#
# avg / total       0.91      0.89      0.89      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 6.68411016464 seconds.
# stratified 5 fold CV 0.981168453327 0.0135512900827
#              precision    recall  f1-score   support
#
#           1       0.79      0.88      0.83       156
#           2       0.99      0.99      0.99      2763
#
# avg / total       0.98      0.98      0.98      2919

# %%
#logistic regression multinomial, lbfgs solver, class weight auto
classifier = "grid_search.GridSearchCV(linear_model.LogisticRegression(penalty='l2',solver='lbfgs', multi_class='multinomial', class_weight='auto'),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 18.2757089138 seconds.
# stratified 5 fold CV 0.734731120171 0.0354068106022
#              precision    recall  f1-score   support
#
#           1       0.43      0.56      0.49       115
#           2       0.86      0.79      0.82       394
#
# avg / total       0.76      0.73      0.75       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 15.8401558399 seconds.
# stratified 5 fold CV 0.691639344262 0.0606576083993
#              precision    recall  f1-score   support
#
#           1       0.61      0.61      0.61       120
#           2       0.74      0.75      0.75       182
#
# avg / total       0.69      0.69      0.69       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 41.7181739807 seconds.
# stratified 5 fold CV 0.888045677489 0.0377241688115
#              precision    recall  f1-score   support
#
#           1       0.47      0.87      0.61       187
#           2       0.98      0.89      0.93      1653
#
# avg / total       0.93      0.89      0.90      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 17.707449913 seconds.
# stratified 5 fold CV 0.706333982473 0.0809210349748
#              precision    recall  f1-score   support
#
#           1       0.33      0.55      0.41        73
#           2       0.88      0.74      0.80       321
#
# avg / total       0.78      0.71      0.73       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 39.7594499588 seconds.
# stratified 5 fold CV 0.726900584795 0.0492965460017
#              precision    recall  f1-score   support
#
#           1       0.22      0.53      0.31       200
#           2       0.92      0.75      0.83      1510
#
# avg / total       0.84      0.73      0.77      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 20.2211279869 seconds.
# stratified 5 fold CV 0.793421529926 0.0378747030953
#              precision    recall  f1-score   support
#
#           1       0.71      0.80      0.75       202
#           2       0.86      0.79      0.82       316
#
# avg / total       0.80      0.79      0.80       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 16.8634998798 seconds.
# stratified 5 fold CV 0.831481481481 0.0753895537816
#              precision    recall  f1-score   support
#
#           1       0.44      0.58      0.50        59
#           2       0.92      0.88      0.90       345
#
# avg / total       0.85      0.83      0.84       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 25.1371850967 seconds.
# stratified 5 fold CV 0.825942634364 0.0640258493346
#              precision    recall  f1-score   support
#
#           1       0.86      0.85      0.85       568
#           2       0.78      0.79      0.78       380
#
# avg / total       0.83      0.83      0.83       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 26.8390378952 seconds.
# stratified 5 fold CV 0.724494975655 0.0543367788706
#              precision    recall  f1-score   support
#
#           1       0.38      0.64      0.47       190
#           2       0.90      0.74      0.81       794
#
# avg / total       0.80      0.72      0.75       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 26.0349209309 seconds.
# stratified 5 fold CV 0.849945724108 0.110974546586
#              precision    recall  f1-score   support
#
#           1       0.07      0.26      0.11        34
#           2       0.97      0.87      0.92       957
#
# avg / total       0.94      0.85      0.89       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 22.5730619431 seconds.
# stratified 5 fold CV 0.878891232786 0.0705201503969
#              precision    recall  f1-score   support
#
#           1       0.39      0.67      0.50        61
#           2       0.97      0.90      0.93       623
#
# avg / total       0.91      0.88      0.89       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 24.1336910725 seconds.
# stratified 5 fold CV 0.664310812602 0.0690408431562
#              precision    recall  f1-score   support
#
#           1       0.46      0.67      0.54       266
#           2       0.83      0.66      0.73       628
#
# avg / total       0.72      0.66      0.68       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 52.2105109692 seconds.
# stratified 5 fold CV 0.829622682661 0.119944244595
#              precision    recall  f1-score   support
#
#           1       0.43      0.85      0.57       350
#           2       0.97      0.83      0.89      2273
#
# avg / total       0.90      0.83      0.85      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 56.3300120831 seconds.
# stratified 5 fold CV 0.970899149958 0.020567988249
#              precision    recall  f1-score   support
#
#           1       0.67      0.92      0.77       156
#           2       1.00      0.97      0.98      2763
#
# avg / total       0.98      0.97      0.97      2919

# %%
#logistic regression 1 vs all, liblinear solver, class weight auto, l1 penalty
classifier = "grid_search.GridSearchCV(linear_model.LogisticRegression(penalty='l1',solver='liblinear', multi_class='ovr', class_weight='auto'),param_grid={'C': [2**-5, 2**-4, 2**-3, 2**-2, 2**-1, 2**0, 2**1, 2**2, 2**3, 2**4, 2**5, 2**6]},cv=5,n_jobs=1)"
main(classifier)

# %%
#KNN 5
classifier = "neighbors.KNeighborsClassifier(n_neighbors=5, weights='distance', algorithm='auto')" 
main(classifier)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 0.134249925613 seconds.
# stratified 5 fold CV 0.764259367113 0.0365742887339
#              precision    recall  f1-score   support
#
#           1       0.47      0.36      0.41       115
#           2       0.82      0.88      0.85       394
#
# avg / total       0.74      0.76      0.75       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0598161220551 seconds.
# stratified 5 fold CV 0.631803278689 0.0820022875776
#              precision    recall  f1-score   support
#
#           1       0.53      0.61      0.57       120
#           2       0.72      0.65      0.68       182
#
# avg / total       0.64      0.63      0.64       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 1.08374190331 seconds.
# stratified 5 fold CV 0.877267653141 0.0432169697735
#              precision    recall  f1-score   support
#
#           1       0.33      0.20      0.25       187
#           2       0.91      0.95      0.93      1653
#
# avg / total       0.85      0.88      0.86      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 0.078460931778 seconds.
# stratified 5 fold CV 0.781935248296 0.0523027610178
#              precision    recall  f1-score   support
#
#           1       0.36      0.22      0.27        73
#           2       0.84      0.91      0.87       321
#
# avg / total       0.75      0.78      0.76       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 0.690768957138 seconds.
# stratified 5 fold CV 0.879532163743 0.00894564826946
#              precision    recall  f1-score   support
#
#           1       0.43      0.10      0.16       200
#           2       0.89      0.98      0.94      1510
#
# avg / total       0.84      0.88      0.84      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 0.105760812759 seconds.
# stratified 5 fold CV 0.699294605071 0.0723733423101
#              precision    recall  f1-score   support
#
#           1       0.60      0.67      0.64       202
#           2       0.77      0.72      0.74       316
#
# avg / total       0.71      0.70      0.70       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 0.0874240398407 seconds.
# stratified 5 fold CV 0.863888888889 0.0107094762796
#              precision    recall  f1-score   support
#
#           1       0.83      0.08      0.15        59
#           2       0.86      1.00      0.93       345
#
# avg / total       0.86      0.86      0.81       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 0.352915048599 seconds.
# stratified 5 fold CV 0.70567529936 0.0410508419169
#              precision    recall  f1-score   support
#
#           1       0.72      0.83      0.77       568
#           2       0.67      0.52      0.59       380
#
# avg / total       0.70      0.71      0.70       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 0.301946878433 seconds.
# stratified 5 fold CV 0.781482440692 0.0153907372142
#              precision    recall  f1-score   support
#
#           1       0.31      0.11      0.16       190
#           2       0.82      0.94      0.87       794
#
# avg / total       0.72      0.78      0.74       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 0.387490987778 seconds.
# stratified 5 fold CV 0.964691838416 0.00308210090915
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        34
#           2       0.97      1.00      0.98       957
#
# avg / total       0.93      0.96      0.95       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 0.167641878128 seconds.
# stratified 5 fold CV 0.884752272855 0.0661002748867
#              precision    recall  f1-score   support
#
#           1       0.37      0.43      0.40        61
#           2       0.94      0.93      0.94       623
#
# avg / total       0.89      0.88      0.89       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 0.273262023926 seconds.
# stratified 5 fold CV 0.629711603512 0.0322892856789
#              precision    recall  f1-score   support
#
#           1       0.35      0.28      0.31       266
#           2       0.72      0.78      0.75       628
#
# avg / total       0.61      0.63      0.62       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 1.86232089996 seconds.
# stratified 5 fold CV 0.829598691385 0.0675366859656
#              precision    recall  f1-score   support
#
#           1       0.31      0.23      0.27       350
#           2       0.89      0.92      0.90      2273
#
# avg / total       0.81      0.83      0.82      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 1.54043602943 seconds.
# stratified 5 fold CV 0.923621816712 0.0305137616943
#              precision    recall  f1-score   support
#
#           1       0.12      0.07      0.09       156
#           2       0.95      0.97      0.96      2763
#
# avg / total       0.90      0.92      0.91      2919

# %% [markdown]
# ## fastgentleboosting

# %%
#run to define main function which loads training data from local .npy files and does CV
import os
import sys
sys.path.insert(1, '/Users/jyhung/Documents/CellProfiler-Analyst_myversion/cpa/')
sys.path.insert(1, '/Users/jyhung/Documents/CellProfiler-Analyst_myversion/')
from dbconnect import *
import threading
from trainingset import TrainingSet
import fastgentleboosting, multiclasssql
from sklearn import cross_validation, metrics
from sklearn import ensemble, naive_bayes, grid_search, svm, lda, qda, tree, multiclass, linear_model, neighbors

directory = '/Users/jyhung/work/projects/cpamulti/Jones_PNAS_2009/'

def fgb(num_learners):
    classifier = fastgentleboosting.FastGentleBoosting()
    
    for dirname, dirnames, filenames in os.walk(directory):
        for filename in sorted(filenames):
            
            if filename.endswith('.npz'):
                print 'Loading training set ...'
                trainingSet=np.load(directory+filename)
                labels=trainingSet['labels']
                values=trainingSet['values']
                print filename, values.shape
                #print labels, values
                #%time classifier.XValidate(labels, values, folds=20, stratified=True)
                
                # convert labels to a matrix with +1/-1 values only (+1 in the column matching the label, 1-indexed)
                num_classes = max(labels)
                num_samples = len(labels)
                
                label_matrix = -np.ones((len(labels), num_classes), np.int32)
                #print zip(range(len(labels)), np.array(labels)-1)
                for i, j in zip(range(len(labels)), np.array(labels)-1):
                    label_matrix[i, j] = 1
                
                #print labels
                #labels = [x-1 for x in labels]
                #print labels
                #print label_matrix
                
                tic()
                print 'Scoring cells 1 ...'
                folds = 5
                scores = np.zeros(folds)
                total_labels = np.zeros(num_samples)
                colnames = np.array(range(values.shape[1]))
                skf = cross_validation.StratifiedKFold(labels, n_folds=folds)
                for i, (train_index, test_index) in enumerate(skf):
                    #print train_index, test_index
                    values_train, values_test = values[train_index], values[test_index]
                    labels_train, labels_test = label_matrix[train_index], label_matrix[test_index]
                    predicted_labels = classifier.Train(colnames, num_learners, labels_train, values_train, test_values=values_test)
                    #print len(predicted_labels), len(predicted_labels[0])
                    predicted_labels = predicted_labels[-1]
                    total_labels[test_index] = total_labels[test_index] + predicted_labels
                    #print label_matrix[test_index, :].argmax(axis=1)
                    #print predicted_labels
                    scores[i] = metrics.accuracy_score(label_matrix[test_index, :].argmax(axis=1), predicted_labels)
                toc()
                print 'stratified 5 fold CV', scores.mean(), scores.std()
                print metrics.classification_report(label_matrix.argmax(axis=1), total_labels)

# %%
fgb(50)
# Out:
# Loading training set ...
# actin_blebs_training.npz (509, 617)
# Scoring cells 1 ...
# Elapsed time is 32.0194680691 seconds.
# stratified 5 fold CV 0.821219180742 0.0742454187269
#              precision    recall  f1-score   support
#
#           0       0.62      0.55      0.58       115
#           1       0.87      0.90      0.89       394
#
# avg / total       0.81      0.82      0.82       509
#
# Loading training set ...
# actin_dots_junctions_training.npz (302, 617)
# Scoring cells 1 ...
# Elapsed time is 24.1298391819 seconds.
# stratified 5 fold CV 0.797704918033 0.0596771850779
#              precision    recall  f1-score   support
#
#           0       0.72      0.80      0.76       120
#           1       0.86      0.80      0.83       182
#
# avg / total       0.80      0.80      0.80       302
#
# Loading training set ...
# anaphase_telophase_training.npz (1840, 617)
# Scoring cells 1 ...
# Elapsed time is 73.0959849358 seconds.
# stratified 5 fold CV 0.943023016609 0.042938750544
#              precision    recall  f1-score   support
#
#           0       0.68      0.84      0.75       187
#           1       0.98      0.95      0.97      1653
#
# avg / total       0.95      0.94      0.95      1840
#
# Loading training set ...
# angular_cell_edges_training.npz (394, 617)
# Scoring cells 1 ...
# Elapsed time is 27.658864975 seconds.
# stratified 5 fold CV 0.823184842584 0.0928180816494
#              precision    recall  f1-score   support
#
#           0       0.52      0.63      0.57        73
#           1       0.91      0.87      0.89       321
#
# avg / total       0.84      0.82      0.83       394
#
# Loading training set ...
# crescent_nuclei_training.npz (1710, 617)
# Scoring cells 1 ...
# Elapsed time is 69.3048639297 seconds.
# stratified 5 fold CV 0.802339181287 0.0583800323122
#              precision    recall  f1-score   support
#
#           0       0.28      0.43      0.34       200
#           1       0.92      0.85      0.88      1510
#
# avg / total       0.84      0.80      0.82      1710
#
# Loading training set ...
# large_spread_training.npz (518, 617)
# Scoring cells 1 ...
# Elapsed time is 31.3465790749 seconds.
# stratified 5 fold CV 0.780124115367 0.0289711394064
#              precision    recall  f1-score   support
#
#           0       0.71      0.73      0.72       202
#           1       0.82      0.81      0.82       316
#
# avg / total       0.78      0.78      0.78       518
#
# Loading training set ...
# long_projections_training.npz (404, 617)
# Scoring cells 1 ...
# Elapsed time is 28.0542268753 seconds.
# stratified 5 fold CV 0.849043209877 0.0620940098319
#              precision    recall  f1-score   support
#
#           0       0.49      0.56      0.52        59
#           1       0.92      0.90      0.91       345
#
# avg / total       0.86      0.85      0.85       404
#
# Loading training set ...
# metaphase_training.npz (948, 617)
# Scoring cells 1 ...
# Elapsed time is 45.0267090797 seconds.
# stratified 5 fold CV 0.872414369256 0.0654737534654
#              precision    recall  f1-score   support
#
#           0       0.88      0.91      0.89       568
#           1       0.85      0.82      0.84       380
#
# avg / total       0.87      0.87      0.87       948
#
# Loading training set ...
# motile_training.npz (984, 617)
# Scoring cells 1 ...
# Elapsed time is 48.6722159386 seconds.
# stratified 5 fold CV 0.759007562416 0.0819572897704
#              precision    recall  f1-score   support
#
#           0       0.41      0.59      0.49       190
#           1       0.89      0.80      0.84       794
#
# avg / total       0.80      0.76      0.77       984
#
# Loading training set ...
# peas_in_a_pod_training.npz (991, 617)
# Scoring cells 1 ...
# Elapsed time is 47.3886749744 seconds.
# stratified 5 fold CV 0.916409870714 0.0543293569663
#              precision    recall  f1-score   support
#
#           0       0.05      0.09      0.07        34
#           1       0.97      0.95      0.96       957
#
# avg / total       0.94      0.92      0.93       991
#
# Loading training set ...
# peripheral_actin_training.npz (684, 617)
# Scoring cells 1 ...
# Elapsed time is 36.6129918098 seconds.
# stratified 5 fold CV 0.927174846454 0.0616489091855
#              precision    recall  f1-score   support
#
#           0       0.58      0.66      0.62        61
#           1       0.97      0.95      0.96       623
#
# avg / total       0.93      0.93      0.93       684
#
# Loading training set ...
# phospho_histone_h3_dots_training.npz (894, 617)
# Scoring cells 1 ...
# Elapsed time is 51.4102189541 seconds.
# stratified 5 fold CV 0.877934634779 0.0687786174056
#              precision    recall  f1-score   support
#
#           0       0.76      0.86      0.81       266
#           1       0.94      0.89      0.91       628
#
# avg / total       0.88      0.88      0.88       894
#
# Loading training set ...
# prometaphase_training.npz (2623, 617)
# Scoring cells 1 ...
# Elapsed time is 100.073165894 seconds.
# stratified 5 fold CV 0.887952744457 0.102691655986
#              precision    recall  f1-score   support
#
#           0       0.56      0.81      0.66       350
#           1       0.97      0.90      0.93      2273
#
# avg / total       0.91      0.89      0.90      2623
#
# Loading training set ...
# prophase_training.npz (2919, 617)
# Scoring cells 1 ...
# Elapsed time is 108.023020983 seconds.
# stratified 5 fold CV 0.985621095541 0.0111554997501
#              precision    recall  f1-score   support
#
#           0       0.84      0.90      0.87       156
#           1       0.99      0.99      0.99      2763
#
# avg / total       0.99      0.99      0.99      2919
